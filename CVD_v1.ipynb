# %%
import numpy as np
import pandas as pd

from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)

# %%
data = pd.read_csv('cardio_data.csv', sep=';')

# %%
data
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
data.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900  19468.865814      1.349571    164.359229     74.205690
# std    28851.302323   2467.251667      0.476838      8.210126     14.395757
# min        0.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25006.750000  17664.000000      1.000000    159.000000     65.000000
# 50%    50001.500000  19703.000000      1.000000    165.000000     72.000000
# 75%    74889.250000  21327.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      1.366871      1.226457      0.088129
# ...

# %%
data.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
data=data.drop(columns=["id"])

# %%
data
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0      18393       2     168    62.0    110     80            1     1      0
# 1      20228       1     156    85.0    140     90            3     1      0
# 2      18857       1     165    64.0    130     70            3     1      0
# 3      17623       2     169    82.0    150    100            1     1      0
# 4      17474       1     156    56.0    100     60            1     1      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995  19240       2     168    76.0    120     80            1     1      1
# 69996  22601       1     158   126.0    140     90            2     2      0
# 69997  19066       2     183   105.0    180     90            3     1      0
# 69998  22431       1     163    72.0    135     80            1     2      0
# 69999  20540       1     170    72.0    120     80            2     1      0
#
#        alco  active  cardio
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.boxplot(data=data, width= 0.5,ax=ax,  fliersize=3)
plt.title("Outliers")
# Out:
# Text(0.5, 1.0, 'Outliers')

# %%
X = data.drop(columns = ['cardio'])
y = data['cardio']

# %%
plt.figure(figsize=(13,10), facecolor='white')
plotnumber = 1

column_1 = ['age','height', 'weight', 'ap_hi','ap_lo']
for column_1 in column_1:
    if plotnumber<=9 :
        ax = plt.subplot(3,3,plotnumber)
        sns.stripplot(y,X[column_1])
    plotnumber+=1

plt.tight_layout()

# %%
corr = X.corr()
f, ax = plt.subplots(figsize = (15,15))
sns.heatmap(corr, annot=True, ax=ax)
# Out:
# <AxesSubplot:>

# %%
#from sklearn.tree import DecisionTreeClassifier
#from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
#from sklearn.model_selection import GridSearchCV,RandomizedSearchCV,train_test_split
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,f1_score,roc_curve, roc_auc_score,classification_report

# %%
knn = KNeighborsClassifier(n_neighbors=3)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %%
knn.fit(X_train,y_train)
knn_pred = knn.predict(X_test)
print(classification_report(y_test,knn_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.68      0.67      7069
#            1       0.66      0.65      0.66      6931
#
#     accuracy                           0.66     14000
#    macro avg       0.66      0.66      0.66     14000
# weighted avg       0.66      0.66      0.66     14000

# %%
error_rate = []

for i in range(1,25):
    
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))

plt.figure(figsize=(10,7));
plt.plot(range(1,25),error_rate,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. kvalue')
#lt.annotate(range(1,25);
plt.xlabel('k-value');
plt.ylabel('Error Rate');

# %%
knn_2 = KNeighborsClassifier(n_neighbors=17)

# %%
knn_2.fit(X_train,y_train)
knn_pred_2 = knn_2.predict(X_test)
print(classification_report(y_test,knn_pred_2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.75      0.72      7069
#            1       0.73      0.66      0.69      6931
#
#     accuracy                           0.71     14000
#    macro avg       0.71      0.71      0.71     14000
# weighted avg       0.71      0.71      0.71     14000

# %%
cm = confusion_matrix(y_test,knn_pred)

# %%
cm_2 = confusion_matrix(y_test,knn_pred_2)

# %%
from sklearn.metrics import ConfusionMatrixDisplay

# %%
cm_display = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=knn.classes_)
cm_display.plot()

# %%
cm_display_2 = ConfusionMatrixDisplay(confusion_matrix=cm_2,display_labels=knn_2.classes_)
cm_display_2.plot()

# %%
error_rate = []

for i in range(1,100):
    
    knn_i = KNeighborsClassifier(n_neighbors=i)
    knn_i.fit(X_train,y_train)
    pred_i = knn_i.predict(X_test)
    error_rate.append(confusion_matrix(y_test,pred_i)[1][0])

plt.figure(figsize=(10,7));
plt.plot(range(1,100),error_rate,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. kvalue')
#lt.annotate(range(1,25);
plt.xlabel('k-value');
plt.ylabel('Error Rate');

# %%
cm[1][0]
# Out:
# 2416

# %%
confusion_matrix(y_test,knn_pred)[1][0]
# Out:
# 2416
